# %% [markdown]
# # Black-capped Petrel - GBIF Records Summary

# %% [markdown]
# ## General Setup

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
#import geopandas as gpd
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 60)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()

# %% [markdown]
# ### Config file
# Some of the scripts below pull common variables from a config file.  This is so in order to reduce redundancy and also facilitates running scripts outside of jupyter notebooks.  However, variables need to be able to be set in notebooks too, so the cell below deletes and then rewrites the config file according to what to you want for this notebook.

# %%
# Set variables in the following text string, not variable assignment below.
text = """#NOTE! this is overwritten by some notebooks, so update everywhere, if adding lines.
sp_id = 'bbcpex0'
summary_name = 'diablotin'
gbif_req_id = 'GBIFr7'
gbif_filter_id = 'GBIFf2'
ebird_req_id = None
ebird_filter_id = None
evaluation = 'eval_gbif1'
workDir = '/Users/nmtarr/Documents/RANGES/'
codeDir = '/Users/nmtarr/Code/range_map_evaluation/'
inDir = workDir + 'Inputs/'
outDir = workDir + 'Outputs/'
default_coordUncertainty = 1000
SRID_dict = {'WGS84': 4326, 'AlbersNAD83': 102008} # Used in file names for output.
spdb = outDir + sp_id + gbif_req_id + gbif_filter_id + '.sqlite'
"""
f = open('config.py', 'w')
f.write(text)
f.close()

import config
species_id = config.sp_id
summary_name = config.summary_name
request_id = config.gbif_req_id
filter_id = config.gbif_filter_id
inDir = config.inDir
outDir = config.outDir
common_name = 'Black-capped Petrel'

# %%
connjup = sqlite3.connect(config.codeDir + 'parameters.sqlite')
cursorjup = connjup.cursor()

# %% [markdown]
# ## Species Concept

# %%
vals = cursorjup.execute("SELECT * FROM species_concepts WHERE species_id = '{0}';".format(species_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('species_concepts')").fetchall()]
pprint.pprint(dict(zip(cols, vals)))
# Out:
# {'bcb_id': None,
#  'breeding_months': '',
#  'common_name': 'black-capped petrel',
#  'detection_distance_meters': 300,
#  'end_year': None,
#  'error_tolerance': 20,
#  'fws_id': 'Pterodroma hasitata',
#  'gap_id': '',
#  'gbif_id': '2481477',
#  'geometry': None,
#  'itis_tsn': '174567',
#  'migratory': '1',
#  'notes': 'Based on FWS SSA, detection distance is a guess.',
#  'pad': 1,
#  'scientific_name': 'Pterodroma hasitata',
#  'species_id': 'bbcpex0',
#  'start_year': 1918,
#  'wintering_months': ''}

# %% [markdown]
# ## Filters

# %%
df1 = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(request_id), con=connjup)
print("THE REQUEST FILTER SET")
print(df1.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id         GBIFr7
# source               GBIF
# lat_range           27,41
# lon_range         -91,-75
# years_range     2018,2019
# months_range         1,12
# geoissue             None
# coordinate           True
# continent            None
# creator           N. Tarr
# notes                None
# Name: 0, dtype: object

# %%
df2 = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(df2.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                                                    GBIFf2
# source                                                         GBIF
# has_coordinate_uncertainty                                        0
# creator                                                     N. Tarr
# notes                         Used for development. SAME as GBIF_f2
# Name: 0, dtype: object

# %% [markdown]
# ## Run Query

# %%
# Run a script that retrieves and filters
# %run 'retrieve_occurrences.py'
# Out:
# No GAP range was retrieved.
# 890 records exist

# %% [markdown]
# ## Results

# %%
gap_range2 = "{0}{1}_range_4326".format(inDir, gap_id)

shp1 = {'file': gap_range2, 'column': None, 'alias': 'GAP range map',
        'drawbounds': False, 'linewidth': .5, 'linecolor': 'y',
        'fillcolor': 'y', 'marker':'s'}

shp2 = {'file': '{0}{1}_circles'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'k',
        'fillcolor': None, 'marker':'o'}

# Display occurrence polygons
if os.path.isfile(gap_range2 + ".shp"):
    map_these=[shp1, shp2]
else:
    map_these=[shp2]
    
title="{1} ({0})".format(years, common_name)
functions.MapShapefilePolygons(map_these=map_these, title=title)

# %% [markdown]
# ### Where were records retrieved from?

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [request_id, filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])
# Out:
# GBIF

# %% [markdown]
# ### How many records made it through the filters?

# %%
conn_occ= sqlite3.connect(config.spdb)
curs_occ = conn_occ.cursor()
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE species_id = '{0}'".format(species_id)).fetchone()
print(str(record_count[0]) + " records made it through the filters")
# Out:
# 890 records made it through the filters

# %% [markdown]
# ### What years were represented in the data?

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(config.gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of occurrences")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# ### What months were represented in the data?

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of occurrences")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# ### What is the distribution of coordinate uncertainty values?

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %% [markdown]
# ### What geodetic datums were present in the data?

# %%
datums = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'datums';").fetchone()[0]
datums = datums.replace('[', '').strip().replace(']', '').replace("'", "")
datums = datums.split()
for datum in datums:
    print(datum)
# Out:
# WGS84

# %% [markdown]
# ### What issues were present in the data?

# %%
issues = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'issues';").fetchone()[0]
issues = issues.replace('[', '').strip().replace(']', '').replace("'", "")
issues = issues.split(',')
for iss in issues:
    print(iss.strip())
# Out:
# GEODETIC_DATUM_ASSUMED_WGS84
# COUNTRY_DERIVED_FROM_COORDINATES
# COORDINATE_ROUNDED

# %% [markdown]
# ### What were the bases of the records?

# %%
bases = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'bases';").fetchone()[0]
bases = bases.replace('[', '').strip().replace(']', '').replace("'", "")
bases = bases.split(",")
for bas in bases:
    print(bas.strip())
# Out:
# HUMAN_OBSERVATION

# %% [markdown]
# ### What were the establishment means?

# %%
establishment = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'establishment';").fetchone()[0]
establishment = establishment.replace('[', '').strip().replace(']', '').replace("'", "")
establishment = establishment.split(',')
for est in establishment:
    print(est.strip())

# %% [markdown]
# ### Identification qualifier

# %%
quali = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'IDqualifier';").fetchone()[0]
quali = quali.replace('[', '').strip().replace(']', '').replace("'", "")
quali = quali.split(',')
for q in quali:
    print(q.strip())

# %% [markdown]
# ### Protocols and sampling protocols

# %%
protos = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'protocols';").fetchone()[0]
protos = protos.replace('[', '').strip().replace(']', '').replace("'", "")
protos = protos.split(',')
for pro in protos:
    print(pro.strip())
# Out:
# DWC_ARCHIVE

# %% [markdown]
# ### Remarks returned ?  With occ_ids?

# %%
remarks = curs_occ.execute("SELECT DISTINCT remarks FROM occurrences;").fetchall()
#remarks = remarks.replace('[', '').strip().replace(']', '').replace("'", "")
#remarks = remarks.split(',')
for rem in remarks:
    if rem[0][0:1] == ';':
        print(rem[0][2:])
    else:
        print(rem[0])
# Out:
# Dare County, North Carolina, US
#
# (35.4271,-75.1475)
# HT-SE PNLV Anfas Mezon du Pak 18.3311x-72.2687
# Gulfstream Off Miami
# US-North Atlantic Ocean (26.4364,-79.8721)
# 12 miles off Boynton Inlet
# Florida, US (26.543, -80.029)
# US-FL-Atlantic Ocean (28.4073,-80.5777)
# Hatteras Pelagic--Gulf Stream
# 2018-May Pelagic - Leg 7
# North Atlantic Ocean (34.9390,-75.2417)
# North Atlantic Ocean (34.8034,-75.3705)
# North Atlantic Ocean (34.8269,-75.3746)
# North Atlantic Ocean (34.8201,-75.4150)
# Hatteras Pelagic--Nearshore Waters
# North Atlantic Ocean (34.9971,-75.2533)
# North Atlantic Ocean (34.8817,-75.4657)
# (34.3905,-75.6060)
# North Atlantic Ocean (34.8979,-75.2816)
# North Atlantic Ocean (34.7398,-75.5336)
# Offshore Palm Beach County
# (28.599, -79.864)
# Norfolk Canyon
# Atlantic Ocean Brevard
# Atlantic Ocean
# US-FL: Offshore Atlantic Ocean (28.59708, -79.89585)
# (32.4731,-76.9024)
# North Atlantic Ocean (34.8861,-75.2370)
# North Atlantic Ocean (34.8396,-75.4490)
# North Atlantic Ocean (34.9551,-75.2175)
# North Atlantic Ocean (34.8470,-75.2471)
# North Atlantic Ocean (34.8769,-75.2181)
# North Atlantic Ocean (34.8564,-75.4505)
# Cape Canaveral Lock
# North Atlantic Ocean (34.8789,-75.4636)
# North Atlantic Ocean (34.8280,-75.3827)
# North Atlantic Ocean (34.8759,-75.2164)
# North Atlantic Ocean (34.8207,-75.3038)
# NOAA 08042018 B
# North Atlantic Ocean (34.9899,-75.1464)
# NOAA 08052018 C
# NOAA 08052018 I
# NOAA 08052018 EF
# NOAA 08052018 L
# Marine Science Center Pelagic
# (28.586, -79.9)
# Cape May pelagic 08132018 C
# North Atlantic Ocean (35.0014,-75.2615)
# North Atlantic Ocean (34.8244,-75.3199)
# Off-shore Palm Beach County
# Cape May pelagic 08132018 A
# Cape May pelagic 08132018 B
# NY 08202018 C
# NY 08202018 B
# NY 08202018 G
# NY 08202018 D
# NY 08202018 F
# big ten.
# Cape May pelagic 08132018 E
# Cape May pelagic 08132018 D
# Cape May pelagic 08132018 F
# US-North Atlantic Ocean, Palm Beach County, FL, US
# Lake Hartwell--Big Oaks & Dam
# NOAA 08042018 J
# NOAA 08042018 I
# NOAA 08052018 D
# NOAA 08042018 K
# North Atlantic Ocean (34.9525,-75.0895)
# North Atlantic 40 miles S Cape Hatteras
# NOAA 08052018 E
# Hudson Canyon
# North Atlantic 30 Miles SSE of Cape Hatteras
# NOAA 08052018 A
# NOAA 08052018 H
# Lake Hartwell--Long Point RA
# N. Atlantic Ocean 50 Miles S Cape Hatteras
# HT-SE PNLV Kay Jim 18.323-72.263

# %% [markdown]
# ### What institutions provided the records?

# %%
institutions = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'institutions';").fetchone()[0]
institutions = institutions.replace('[', '').strip().replace(']', '').replace("'", "")
institutions = institutions.split(',')
for ins in institutions:
    print(ins.strip())
# Out:
# CLO
# iNaturalist

# %% [markdown]
# ### What data collections were included?

# %%
collections = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'collections';").fetchone()[0]
collections = collections.replace('[', '').strip().replace(']', '').replace("'", "")
collections = collections.split(',')
for colls in collections:
    print(colls.strip())
# Out:
# EBIRD_CB
# Observations
# EBIRD

# %% [markdown]
# ### Were there duplicate records?

# %%
dups0 = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences GROUP BY geom_xy4326, occurrenceDate;").fetchall()
dups1 = [x[0] for x in dups0]
dups2 = [x for x in dups1 if x > 1]
print(str(len(dups2)) + ' records were duplicates based on xy coordinate and date-time')
# Out:
# 80 records were duplicates based on xy coordinate and date-time

# %% [markdown]
# ### What keys/fields were returned for the records?

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ, index_col='index')
fields_summary.index.name = 'field'
print(fields_summary)
# Out:
#                                       included(n)  populated(n)
# field
# acceptedScientificName                        890           890
# acceptedTaxonKey                              890           890
# basisOfRecord                                 890           890
# catalogNumber                                 890           890
# class                                         890           890
# classKey                                      890           890
# collectionCode                                890           890
# coordinateUncertaintyInMeters                  13            13
# country                                       890           890
# countryCode                                   890           890
# county                                        872           872
# crawlId                                       890           890
# datasetKey                                    890           890
# datasetName                                    13            13
# dateIdentified                                 13            13
# day                                           890           890
# decimalLatitude                               890           890
# decimalLongitude                              890           890
# eventDate                                     890           890
# eventTime                                      13            13
# extensions                                    890             0
# facts                                         890             0
# family                                        890           890
# familyKey                                     890           890
# gbifID                                        890           890
# genericName                                   890           890
# genus                                         890           890
# genusKey                                      890           890
# geodeticDatum                                 890           890
# http://unknown.org/occurrenceDetails           13            13
# identificationID                               13            13
# identifier                                    890           890
# identifiers                                   890             0
# individualCount                               876           876
# informationWithheld                            13            13
# installationKey                               890           890
# institutionCode                               890           890
# issues                                        890           380
# key                                           890           890
# kingdom                                       890           890
# kingdomKey                                    890           890
# lastCrawled                                   890           890
# lastInterpreted                               890           890
# lastParsed                                    890           890
# license                                       890           890
# locality                                      877           877
# media                                          13            13
# modified                                       13            13
# month                                         890           890
# networkKeys                                   890             0
# occurrenceID                                  890           890
# occurrenceRemarks                              11            11
# order                                         890           890
# orderKey                                      890           890
# phylum                                        890           890
# phylumKey                                     890           890
# protocol                                      890           890
# publishingCountry                             890           890
# publishingOrgKey                              890           890
# recordedBy                                    890           890
# references                                     13            13
# relations                                     890             0
# rights                                         13            13
# rightsHolder                                   13            13
# scientificName                                890           890
# species                                       890           890
# speciesKey                                    890           890
# specificEpithet                               890           890
# stateProvince                                 877           877
# taxonID                                        13            13
# taxonKey                                      890           890
# taxonRank                                     890           890
# taxonomicStatus                               890           890
# verbatimEventDate                              13            13
# year                                          890           890

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
# Out:
# 0:01:24.332217
