# %% [markdown]
# # Black-capped Petrel - GBIF Records Summary

# %% [markdown]
# ## General Setup

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
#import geopandas as gpd
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 60)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()

# %% [markdown]
# ### Config file
# Some of the scripts below pull common variables from a config file.  This is so in order to reduce redundancy and also facilitates running scripts outside of jupyter notebooks.  However, variables need to be able to be set in notebooks too, so the cell below deletes and then rewrites the config file according to what to you want for this notebook.

# %%
# Set variables in the following text string, not variable assignment below.
text = """#NOTE! this is overwritten by some notebooks, so update everywhere, if adding lines.
sp_id = 'bbcpex0'
summary_name = 'diablotin'
gbif_req_id = 'GBIFr7'
gbif_filter_id = 'GBIFf2'
ebird_req_id = None
ebird_filter_id = None
evaluation = 'eval_gbif1'
workDir = '/Users/nmtarr/Documents/RANGES/'
codeDir = '/Users/nmtarr/Code/range_map_evaluation/'
inDir = workDir + 'Inputs/'
outDir = workDir + 'Outputs/'
default_coordUncertainty = 1000
SRID_dict = {'WGS84': 4326, 'AlbersNAD83': 102008} # Used in file names for output.
spdb = outDir + sp_id + gbif_req_id + gbif_filter_id + '.sqlite'
"""
f = open('config.py', 'w')
f.write(text)
f.close()

import config
species_id = config.sp_id
summary_name = config.summary_name
request_id = config.gbif_req_id
filter_id = config.gbif_filter_id
inDir = config.inDir
outDir = config.outDir
common_name = 'Black-capped Petrel'

# %%
connjup = sqlite3.connect(config.codeDir + 'parameters.sqlite')
cursorjup = connjup.cursor()

# %% [markdown]
# ## Species Concept

# %%
vals = cursorjup.execute("SELECT * FROM species_concepts WHERE species_id = '{0}';".format(species_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('species_concepts')").fetchall()]
pprint.pprint(dict(zip(cols, vals)))
# Out:
# {'bcb_id': None,
#  'breeding_months': '',
#  'common_name': 'black-capped petrel',
#  'detection_distance_meters': 300,
#  'end_year': None,
#  'error_tolerance': 20,
#  'fws_id': 'Pterodroma hasitata',
#  'gap_id': '',
#  'gbif_id': '2481477',
#  'geometry': None,
#  'itis_tsn': '174567',
#  'migratory': '1',
#  'notes': 'Based on FWS SSA, detection distance is a guess.',
#  'pad': 1,
#  'scientific_name': 'Pterodroma hasitata',
#  'species_id': 'bbcpex0',
#  'start_year': 1918,
#  'wintering_months': ''}

# %% [markdown]
# ## Filters

# %%
df1 = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(request_id), con=connjup)
print("THE REQUEST FILTER SET")
print(df1.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id         GBIFr7
# source               GBIF
# lat_range           27,41
# lon_range         -91,-75
# years_range     2018,2019
# months_range         1,12
# geoissue             None
# coordinate           True
# continent            None
# creator           N. Tarr
# notes                None
# Name: 0, dtype: object

# %%
df2 = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(df2.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                                                    GBIFf2
# source                                                         GBIF
# has_coordinate_uncertainty                                        0
# creator                                                     N. Tarr
# notes                         Used for development. SAME as GBIF_f2
# Name: 0, dtype: object

# %% [markdown]
# ## Run Query

# %%
# Run a script that retrieves and filters
# %run 'retrieve_occurrences.py'
# Out:
# No GAP range was retrieved.
# 890 records exist
# ; Gulfstream Off Miami
# ; (35.4271,-75.1475)
# ; HT-SE PNLV Anfas Mezon du Pak 18.3311x-72.2687
# ; HT-SE PNLV Anfas Mezon du Pak 18.3311x-72.2687
# ; Norfolk Canyon
# ; Marine Science Center Pelagic
# ; North Atlantic Ocean (34.8817,-75.4657)
# ; Hatteras Pelagic--Gulf Stream
# ; North Atlantic Ocean (34.8759,-75.2164)
# ; Hatteras Pelagic--Gulf Stream
# Dare County, North Carolina, US
# ; 2018-May Pelagic - Leg 7
# ; North Atlantic Ocean (34.9390,-75.2417)
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Nearshore Waters
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; 2018-May Pelagic - Leg 7
# Dare County, North Carolina, US
# ; US-North Atlantic Ocean, Palm Beach County, FL, US
# ; Hatteras Pelagic--Nearshore Waters
# ; Hatteras Pelagic--Gulf Stream
# ; US-North Atlantic Ocean (26.4364,-79.8721)
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Atlantic Ocean Brevard
# ; Hatteras Pelagic--Gulf Stream
# ; North Atlantic Ocean (34.9390,-75.2417)
# ; Hatteras Pelagic--Nearshore Waters
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; North Atlantic Ocean (34.8564,-75.4505)
# Dare County, North Carolina, US
# ; North Atlantic Ocean (34.8201,-75.4150)
# ; Hatteras Pelagic--Gulf Stream
# Dare County, North Carolina, US
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Nearshore Waters
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; US-FL: Offshore Atlantic Ocean (28.59708, -79.89585)
# ; North Atlantic Ocean (34.8861,-75.2370)
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; 2018-May Pelagic - Leg 7
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; North Atlantic Ocean (34.8769,-75.2181)
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Nearshore Waters
# ; Hatteras Pelagic--Gulf Stream
# ; North Atlantic Ocean (34.8769,-75.2181)
# ; 2018-May Pelagic - Leg 7
# ; 2018-May Pelagic - Leg 7
# ; 12 miles off Boynton Inlet
# ; Hatteras Pelagic--Gulf Stream
# Dare County, North Carolina, US
# ; Hatteras Pelagic--Nearshore Waters
# ; North Atlantic Ocean (34.9390,-75.2417)
# ; Hatteras Pelagic--Nearshore Waters
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Nearshore Waters
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Nearshore Waters
# Dare County, North Carolina, US
# Dare County, North Carolina, US
# ; North Atlantic Ocean (34.8034,-75.3705)
# ; 2018-May Pelagic - Leg 7
# ; US-North Atlantic Ocean (26.4364,-79.8721)
# ; North Atlantic Ocean (34.8207,-75.3038)
# ; (28.599, -79.864)
# ; Hatteras Pelagic--Gulf Stream
# ; US-FL-Atlantic Ocean (28.4073,-80.5777)
# ; North Atlantic Ocean (35.0014,-75.2615)
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; North Atlantic Ocean (34.8034,-75.3705)
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; North Atlantic Ocean (34.8201,-75.4150)
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; 2018-May Pelagic - Leg 7
# ; Florida, US (26.543, -80.029)
# ; Cape Canaveral Lock
# Dare County, North Carolina, US
# ; Hatteras Pelagic--Gulf Stream
# ; (34.3905,-75.6060)
# ; North Atlantic Ocean (34.8817,-75.4657)
# ; 2018-May Pelagic - Leg 7
# ; Hatteras Pelagic--Gulf Stream
# ; 2018-May Pelagic - Leg 7
# ; North Atlantic Ocean (34.8244,-75.3199)
# ; Hatteras Pelagic--Gulf Stream
# ; 2018-May Pelagic - Leg 7
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; North Atlantic Ocean (34.8564,-75.4505)
# ; 2018-May Pelagic - Leg 7
# ; Hatteras Pelagic--Gulf Stream
# ; Offshore Palm Beach County
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; North Atlantic Ocean (34.8861,-75.2370)
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; North Atlantic Ocean (34.9971,-75.2533)
# ; Hatteras Pelagic--Gulf Stream
# ; 2018-May Pelagic - Leg 7
# ; North Atlantic Ocean (34.8280,-75.3827)
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Nearshore Waters
# ; Hatteras Pelagic--Gulf Stream
# Dare County, North Carolina, US
# ; Hatteras Pelagic--Nearshore Waters
# ; Hatteras Pelagic--Gulf Stream
# ; US-North Atlantic Ocean (26.4364,-79.8721)
# ; (28.586, -79.9)
# ; Hatteras Pelagic--Gulf Stream
# ; 2018-May Pelagic - Leg 7
# ; 2018-May Pelagic - Leg 7
# ; Hatteras Pelagic--Nearshore Waters
# ; Hatteras Pelagic--Gulf Stream
# ; North Atlantic Ocean (34.8201,-75.4150)
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Nearshore Waters
# ; US-North Atlantic Ocean (26.4364,-79.8721)
# ; Hatteras Pelagic--Gulf Stream
# ; Hatteras Pelagic--Gulf Stream
# ; North Atlantic Ocean (34.8034,-75.3705)
# ; Hatteras Pelagic--Gulf Stream
# ; US-FL-Atlantic Ocean (28.4073,-80.5777)
# ; North Atlantic Ocean (34.8396,-75.4490)
# ; Hatteras Pelagic--Nearshore Waters
# ; 2018-May Pelagic - Leg 7
# ; Hatteras Pelagic--Gulf Stream
# 
19T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Gulf Stream', 'gbifID': '2211735895', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS668648860', 'remarks': '; Hatteras Pelagic--Gulf Stream'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 129, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.245361, 'decimalLatitude': 34.858891, 'year': 2018, 'month': 10, 'day': 13, 'eventDate': '2018-10-13T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Gulf Stream', 'gbifID': '2219131870', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS666691126', 'remarks': '; Hatteras Pelagic--Gulf Stream'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 21, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.40741, 'decimalLatitude': 35.096092, 'year': 2018, 'month': 10, 'day': 13, 'eventDate': '2018-10-13T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Nearshore Waters', 'gbifID': '2194586319', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS666864760', 'remarks': '; Hatteras Pelagic--Nearshore Waters'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 95, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.245361, 'decimalLatitude': 34.858891, 'year': 2018, 'month': 10, 'day': 6, 'eventDate': '2018-10-06T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Gulf Stream', 'gbifID': '2204526106', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS664347073', 'remarks': '; Hatteras Pelagic--Gulf Stream'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 48, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.245361, 'decimalLatitude': 34.858891, 'year': 2018, 'month': 10, 'day': 19, 'eventDate': '2018-10-19T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Gulf Stream', 'gbifID': '2211790345', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS668635403', 'remarks': '; Hatteras Pelagic--Gulf Stream'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 48, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.245361, 'decimalLatitude': 34.858891, 'year': 2018, 'month': 10, 'day': 19, 'eventDate': '2018-10-19T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Gulf Stream', 'gbifID': '2208572959', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS668629700', 'remarks': '; Hatteras Pelagic--Gulf Stream'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 95, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.245361, 'decimalLatitude': 34.858891, 'year': 2018, 'month': 10, 'day': 6, 'eventDate': '2018-10-06T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Gulf Stream', 'gbifID': '2216924864', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS664322067', 'remarks': '; Hatteras Pelagic--Gulf Stream'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 21, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.40741, 'decimalLatitude': 35.096092, 'year': 2018, 'month': 10, 'day': 13, 'eventDate': '2018-10-13T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Nearshore Waters', 'gbifID': '2194357168', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS666722298', 'remarks': '; Hatteras Pelagic--Nearshore Waters'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 95, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.245361, 'decimalLatitude': 34.858891, 'year': 2018, 'month': 10, 'day': 6, 'eventDate': '2018-10-06T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Gulf Stream', 'gbifID': '2216915033', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS664345478', 'remarks': '; Hatteras Pelagic--Gulf Stream'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 129, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.245361, 'decimalLatitude': 34.858891, 'year': 2018, 'month': 10, 'day': 13, 'eventDate': '2018-10-13T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Gulf Stream', 'gbifID': '2194370983', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS666721366', 'remarks': '; Hatteras Pelagic--Gulf Stream'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 21, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.40741, 'decimalLatitude': 35.096092, 'year': 2018, 'month': 10, 'day': 13, 'eventDate': '2018-10-13T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Nearshore Waters', 'gbifID': '2209819853', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS666766002', 'remarks': '; Hatteras Pelagic--Nearshore Waters'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 48, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.245361, 'decimalLatitude': 34.858891, 'year': 2018, 'month': 10, 'day': 19, 'eventDate': '2018-10-19T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Gulf Stream', 'gbifID': '2196243949', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS668412299', 'remarks': '; Hatteras Pelagic--Gulf Stream'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 21, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.40741, 'decimalLatitude': 35.096092, 'year': 2018, 'month': 10, 'day': 13, 'eventDate': '2018-10-13T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Nearshore Waters', 'gbifID': '2219121088', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS666693453', 'remarks': '; Hatteras Pelagic--Nearshore Waters'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 129, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.245361, 'decimalLatitude': 34.858891, 'year': 2018, 'month': 10, 'day': 13, 'eventDate': '2018-10-13T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Gulf Stream', 'gbifID': '2194326660', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS666693539', 'remarks': '; Hatteras Pelagic--Gulf Stream'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 2, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.40741, 'decimalLatitude': 35.096092, 'year': 2018, 'month': 10, 'day': 6, 'eventDate': '2018-10-06T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Nearshore Waters', 'gbifID': '2192174569', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS664298795', 'remarks': '; Hatteras Pelagic--Nearshore Waters'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 21, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.40741, 'decimalLatitude': 35.096092, 'year': 2018, 'month': 10, 'day': 13, 'eventDate': '2018-10-13T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Nearshore Waters', 'gbifID': '2206445765', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS666691255', 'remarks': '; Hatteras Pelagic--Nearshore Waters'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 21, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.40741, 'decimalLatitude': 35.096092, 'year': 2018, 'month': 10, 'day': 13, 'eventDate': '2018-10-13T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'Hatteras Pelagic--Nearshore Waters', 'gbifID': '2194105606', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS666477151', 'remarks': '; Hatteras Pelagic--Nearshore Waters'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 3, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -72.262908, 'decimalLatitude': 18.322677, 'year': 2018, 'month': 11, 'day': 22, 'eventDate': '2018-11-22T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'HT-SE PNLV Kay Jim 18.323-72.263', 'gbifID': '2229409644', 'occurrenceID': 'URN:catalog:CLO:EBIRD_CB:OBS679537042', 'remarks': '; HT-SE PNLV Kay Jim 18.323-72.263'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -72.262908, 'decimalLatitude': 18.322677, 'year': 2018, 'month': 11, 'day': 22, 'eventDate': '2018-11-22T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'HT-SE PNLV Kay Jim 18.323-72.263', 'gbifID': '2206766390', 'occurrenceID': 'URN:catalog:CLO:EBIRD_CB:OBS679536648', 'remarks': '; HT-SE PNLV Kay Jim 18.323-72.263'}
# 'dataGeneralizations'
# {'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2481477, 'scientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'acceptedScientificName': 'Pterodroma hasitata (Kuhl, 1820)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -72.262908, 'decimalLatitude': 18.322677, 'year': 2018, 'month': 11, 'day': 28, 'eventDate': '2018-11-28T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'locality': 'HT-SE PNLV Kay Jim 18.323-72.263', 'gbifID': '2230615212', 'occurrenceID': 'URN:catalog:CLO:EBIRD_CB:OBS681645501', 'remarks': '; HT-SE PNLV Kay Jim 18.323-72.263'}

# %% [markdown]
# ## Results

# %%
gap_range2 = "{0}{1}_range_4326".format(inDir, gap_id)

shp1 = {'file': gap_range2, 'column': None, 'alias': 'GAP range map',
        'drawbounds': False, 'linewidth': .5, 'linecolor': 'y',
        'fillcolor': 'y', 'marker':'s'}

shp2 = {'file': '{0}{1}_circles'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'k',
        'fillcolor': None, 'marker':'o'}

# Display occurrence polygons
if os.path.isfile(gap_range2 + ".shp"):
    map_these=[shp1, shp2]
else:
    map_these=[shp2]
    
title="{1} ({0})".format(years, common_name)
functions.MapShapefilePolygons(map_these=map_these, title=title)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-df1df33177ff> in <module>
#      16
#      17 title="{1} ({0})".format(years, common_name)
# ---> 18 functions.MapShapefilePolygons(map_these=map_these, title=title)
#
# ~/Code/range_map_evaluation/repo_functions.py in MapShapefilePolygons(map_these, title)
#      54                                   drawbounds=mapfile['drawbounds'],
#      55                                   linewidth=mapfile['linewidth'],
# ---> 56                                   color=mapfile['linecolor'])
#      57                 # Empty scatter plot for the legend
#      58                 plt.scatter([], [], c='', edgecolor=mapfile['linecolor'],
#
# ~/miniconda3/envs/range_eval/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py in readshapefile(self, shapefile, name, drawbounds, zorder, linewidth, color, antialiased, ax, default_encoding)
#    2150         coordinates using the shpproj utility from the shapelib tools
#    2151         (http://shapelib.maptools.org/shapelib-tools.html)""")
# -> 2152         shptype = shf.shapes()[0].shapeType
#    2153         bbox = shf.bbox.tolist()
#    2154         info = (shf.numRecords,shptype,bbox[0:2]+[0.,0.],bbox[2:]+[0.,0.])
#
# IndexError: list index out of range

# %% [markdown]
# ### Where were records retrieved from?

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [request_id, filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

# %% [markdown]
# ### How many records made it through the filters?

# %%
conn_occ= sqlite3.connect(config.spdb)
curs_occ = conn_occ.cursor()
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE species_id = '{0}'".format(species_id)).fetchone()
print(str(record_count[0]) + " records made it through the filters")

# %% [markdown]
# ### What years were represented in the data?

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(config.gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of occurrences")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")

# %% [markdown]
# ### What months were represented in the data?

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of occurrences")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")

# %% [markdown]
# ### What is the distribution of coordinate uncertainty values?

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")

# %% [markdown]
# ### What geodetic datums were present in the data?

# %%
datums = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'datums';").fetchone()[0]
datums = datums.replace('[', '').strip().replace(']', '').replace("'", "")
datums = datums.split()
for datum in datums:
    print(datum)

# %% [markdown]
# ### What issues were present in the data?

# %%
issues = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'issues';").fetchone()[0]
issues = issues.replace('[', '').strip().replace(']', '').replace("'", "")
issues = issues.split(',')
for iss in issues:
    print(iss.strip())

# %% [markdown]
# ### What were the bases of the records?

# %%
bases = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'bases';").fetchone()[0]
bases = bases.replace('[', '').strip().replace(']', '').replace("'", "")
bases = bases.split(",")
for bas in bases:
    print(bas.strip())

# %% [markdown]
# ### What were the establishment means?

# %% [markdown]
# ### Identification qualifier

# %% [markdown]
# ### Protocols and sampling protocols

# %% [markdown]
# ### Remarks returned ?  With occ_ids?

# %% [markdown]
# ### What institutions provided the records?

# %%
institutions = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'institutions';").fetchone()[0]
institutions = institutions.replace('[', '').strip().replace(']', '').replace("'", "")
institutions = institutions.split(',')
for ins in institutions:
    print(ins.strip())

# %% [markdown]
# ### What data collections were included?

# %%
collections = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'collections';").fetchone()[0]
collections = collections.replace('[', '').strip().replace(']', '').replace("'", "")
collections = collections.split(',')
for colls in collections:
    print(colls.strip())

# %% [markdown]
# ### Were there duplicate records?

# %%
dups0 = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences GROUP BY geom_xy4326, occurrenceDate;").fetchall()
dups1 = [x[0] for x in dups0]
dups2 = [x for x in dups1 if x > 1]
print(str(len(dups2)) + ' records were duplicates based on xy coordinate and date-time')

# %% [markdown]
# ### What keys/fields were returned for the records?

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ, index_col='index')
fields_summary.index.name = 'field'
print(fields_summary)

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
