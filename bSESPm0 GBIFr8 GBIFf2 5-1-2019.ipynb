# %% [markdown]
# # MacGillivray's Seaside Sparrow - GBIF Records Summary

# %% [markdown]
# ## General Setup

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
#import geopandas as gpd
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 60)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()

# %% [markdown]
# ### Config file
# Some of the scripts below pull common variables from a config file.  This is so in order to reduce redundancy and also facilitates running scripts outside of jupyter notebooks.  However, variables need to be able to be set in notebooks too, so the cell below deletes and then rewrites the config file according to what to you want for this notebook.

# %%
# Set variables in the following text string, not variable assignment below.
text = """#NOTE! this is overwritten by some notebooks, so update everywhere, if adding lines.
sp_id = 'bsespm0'
summary_name = 'MacGillivray'
gbif_req_id = 'GBIFr8'
gbif_filter_id = 'GBIFf2'
ebird_req_id = None
ebird_filter_id = None
evaluation = 'eval_gbif1'
workDir = '/Users/nmtarr/Documents/RANGES/'
codeDir = '/Users/nmtarr/Code/range_map_evaluation/'
inDir = workDir + 'Inputs/'
outDir = workDir + 'Outputs/'
default_coordUncertainty = 1000
SRID_dict = {'WGS84': 4326, 'AlbersNAD83': 102008} # Used in file names for output.
spdb = outDir + sp_id + gbif_req_id + gbif_filter_id + '.sqlite'
"""
f = open('config.py', 'w')
f.write(text)
f.close()

import config
species_id = config.sp_id
summary_name = config.summary_name
request_id = config.gbif_req_id
filter_id = config.gbif_filter_id
inDir = config.inDir
outDir = config.outDir
common_name = "MacGillivray's Seaside Sparrow"

# %%
connjup = sqlite3.connect(config.codeDir + 'parameters.sqlite')
cursorjup = connjup.cursor()

# %% [markdown]
# ## Species Concept

# %%
vals = cursorjup.execute("SELECT * FROM species_concepts WHERE species_id = '{0}';".format(species_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('species_concepts')").fetchall()]
pprint.pprint(dict(zip(cols, vals)))
# Out:
# {'bcb_id': None,
#  'breeding_months': '',
#  'common_name': "macgillivray's seaside sparrow",
#  'detection_distance_meters': 200,
#  'end_year': None,
#  'error_tolerance': 20,
#  'fws_id': 'Ammodramus maritimus macgillivraii',
#  'gap_id': None,
#  'gbif_id': '6173504',
#  'geometry': None,
#  'itis_tsn': '202313',
#  'migratory': None,
#  'notes': 'Based on FWS SSA information.  Note that the taxonomy is '
#           'complicated.  Another subspecies may be synonymous and therefore '
#           'should be included (?).  More work is needed on this entry.',
#  'pad': 1,
#  'scientific_name': 'Ammodramus maritimus macgillivraii',
#  'species_id': 'bsespm0',
#  'start_year': 1899,
#  'wintering_months': ''}

# %% [markdown]
# ## Filters

# %%
df1 = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(request_id), con=connjup)
print("THE REQUEST FILTER SET")
print(df1.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id                                  GBIFr8
# source                                        GBIF
# lat_range                                    27,41
# lon_range                                  -91,-75
# years_range                             1920, 2020
# months_range                                  1,12
# geoissue                                      None
# coordinate                                    True
# continent                                     None
# creator                                    N. Tarr
# notes           Developed for neuse river waterdog
# Name: 0, dtype: object

# %%
df2 = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(df2.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                                                    GBIFf2
# source                                                         GBIF
# has_coordinate_uncertainty                                        0
# creator                                                     N. Tarr
# notes                         Used for development. SAME as GBIF_f2
# Name: 0, dtype: object

# %% [markdown]
# ## Run Query

# %%
# Run a script that retrieves and filters
# %run 'retrieve_occurrences.py'
# Out:
# No GAP range was retrieved.
# 48 records exist

# %% [markdown]
# ## Results

# %%
gap_range2 = "{0}{1}_range_4326".format(inDir, gap_id)

shp1 = {'file': gap_range2, 'column': None, 'alias': 'GAP range map',
        'drawbounds': False, 'linewidth': .5, 'linecolor': 'y',
        'fillcolor': 'y', 'marker':'s'}

shp2 = {'file': '{0}{1}_circles'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'k',
        'fillcolor': None, 'marker':'o'}

# Display occurrence polygons
if os.path.isfile(gap_range2 + ".shp"):
    map_these=[shp1, shp2]
else:
    map_these=[shp2]
    
title="{1} ({0})".format(years, common_name)
functions.MapShapefilePolygons(map_these=map_these, title=title)

# %% [markdown]
# ### Where were records retrieved from?

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [request_id, filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])
# Out:
# GBIF

# %% [markdown]
# ### How many records made it through the filters?

# %%
conn_occ= sqlite3.connect(config.spdb)
curs_occ = conn_occ.cursor()
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE species_id = '{0}'".format(species_id)).fetchone()
print(str(record_count[0]) + " records made it through the filters")
# Out:
# 48 records made it through the filters

# %% [markdown]
# ### What years were represented in the data?

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(config.gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of occurrences")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# ### What months were represented in the data?

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of occurrences")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# ### What is the distribution of coordinate uncertainty values?

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %% [markdown]
# ### What geodetic datums were present in the data?

# %%
datums = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'datums';").fetchone()[0]
datums = datums.replace('[', '').strip().replace(']', '').replace("'", "")
datums = datums.split()
for datum in datums:
    print(datum)
# Out:
# WGS84

# %% [markdown]
# ### What issues were present in the data?

# %%
issues = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'issues';").fetchone()[0]
issues = issues.replace('[', '').strip().replace(']', '').replace("'", "")
issues = issues.split(',')
for iss in issues:
    print(iss.strip())
# Out:
# BASIS_OF_RECORD_INVALID
# COORDINATE_REPROJECTED
# GEODETIC_DATUM_ASSUMED_WGS84
# COORDINATE_ROUNDED

# %% [markdown]
# ### What were the bases of the records?

# %%
bases = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'bases';").fetchone()[0]
bases = bases.replace('[', '').strip().replace(']', '').replace("'", "")
bases = bases.split(",")
for bas in bases:
    print(bas.strip())
# Out:
# PRESERVED_SPECIMEN
# UNKNOWN

# %% [markdown]
# ### What institutions provided the records?

# %%
institutions = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'institutions';").fetchone()[0]
institutions = institutions.replace('[', '').strip().replace(']', '').replace("'", "")
institutions = institutions.split(',')
for ins in institutions:
    print(ins.strip())
# Out:
# http://biocol.org/urn:lsid:biocol.org:col:34940
# urn:lsid:biocol.org:col:34777
# ROM
# http://biocol.org/urn:lsid:biocol.org:col:34795
# PMAE
# http://grbio.org/cool/iakn-125z
# urn:lsid:biocol.org:col:34854

# %% [markdown]
# ### What data collections were included?

# %%
collections = curs_occ.execute("SELECT vals FROM values_of_interest WHERE field = 'collections';").fetchone()[0]
collections = collections.replace('[', '').strip().replace(']', '').replace("'", "")
collections = collections.split(',')
for colls in collections:
    print(colls.strip())
# Out:
# Bird
# Birds
# Bird specimens
# Provincial Museum of Alberta

# %% [markdown]
# ### Were there duplicate records?

# %%
dups0 = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences GROUP BY geom_xy4326, occurrenceDate;").fetchall()
dups1 = [x[0] for x in dups0]
dups2 = [x for x in dups1 if x > 1]
print(str(len(dups2)) + ' records were duplicates based on xy coordinate and date-time')
# Out:
# 8 records were duplicates based on xy coordinate and date-time

# %% [markdown]
# ### What keys/fields were returned for the records?

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ, index_col='index')
fields_summary.index.name = 'field'
print(fields_summary)
# Out:
#                                   included(n)  populated(n)
# field
# acceptedScientificName                     48            48
# acceptedTaxonKey                           48            48
# accessRights                               47            47
# basisOfRecord                              48            48
# catalogNumber                              48            48
# class                                      48            48
# classKey                                   48            48
# collectionCode                             48            48
# collectionID                               46            46
# continent                                  47            47
# coordinateUncertaintyInMeters              38            38
# country                                    48            48
# countryCode                                48            48
# county                                     47            47
# crawlId                                    48            48
# dataGeneralizations                         9             9
# datasetID                                   9             9
# datasetKey                                 48            48
# datasetName                                23            23
# dateIdentified                             15            15
# day                                        48            48
# decimalLatitude                            48            48
# decimalLongitude                           48            48
# disposition                                 9             9
# dynamicProperties                          29            29
# endDayOfYear                               28            28
# establishmentMeans                         14            14
# eventDate                                  48            48
# eventTime                                   1             1
# extensions                                 48             0
# facts                                      48             0
# family                                     48            48
# familyKey                                  48            48
# fieldNumber                                 7             7
# gbifID                                     48            48
# genericName                                48            48
# genus                                      48            48
# genusKey                                   48            48
# geodeticDatum                              48            48
# georeferenceProtocol                       47            47
# georeferenceRemarks                         2             2
# georeferenceSources                        38            38
# georeferenceVerificationStatus             38            38
# georeferencedBy                            31            31
# georeferencedDate                          38            38
# higherClassification                       47            47
# higherGeography                            47            47
# identificationQualifier                    15            15
# identificationVerificationStatus           15            15
# identifiedBy                               15            15
# identifier                                 48            48
# identifiers                                48             0
# individualCount                            15            15
# informationWithheld                         1             1
# infraspecificEpithet                       48            48
# installationKey                            48            48
# institutionCode                            48            48
# institutionID                              38            38
# island                                      8             8
# issues                                     48            47
# key                                        48            48
# kingdom                                    48            48
# kingdomKey                                 48            48
# language                                   47            47
# lastCrawled                                48            48
# lastInterpreted                            48            48
# lastParsed                                 48            48
# license                                    48            48
# lifeStage                                  16            16
# locality                                   48            48
# locationAccordingTo                        15            15
# locationRemarks                             9             9
# modified                                   38            38
# month                                      48            48
# networkKeys                                48            15
# nomenclaturalCode                          38            38
# occurrenceID                               47            47
# occurrenceRemarks                           6             6
# occurrenceStatus                           14            14
# order                                      48            48
# orderKey                                   48            48
# organismID                                 24            24
# otherCatalogNumbers                        14            14
# ownerInstitutionCode                        9             9
# phylum                                     48            48
# phylumKey                                  48            48
# preparations                               47            47
# previousIdentifications                    15            15
# protocol                                   48            48
# publishingCountry                          48            48
# publishingOrgKey                           48            48
# recordNumber                               39            39
# recordedBy                                 39            39
# references                                 29            29
# relations                                  48             0
# reproductiveCondition                       8             8
# rightsHolder                               18            18
# scientificName                             48            48
# sex                                        45            45
# species                                    48            48
# speciesKey                                 48            48
# specificEpithet                            48            48
# startDayOfYear                             23            23
# stateProvince                              48            48
# taxonKey                                   48            48
# taxonRank                                  48            48
# taxonomicStatus                            48            48
# type                                       47            47
# verbatimCoordinateSystem                   22            22
# verbatimElevation                           9             9
# verbatimEventDate                          38            38
# verbatimLocality                           38            38
# year                                       48            48

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
# Out:
# 0:01:49.421846
