# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-whitegrid')

fig = plt.figure()
ax = plt.axes()

x = np.linspace(0,10,1000)
ax.plot(x, np.sin(x), label='sin')
ax.plot(x, np.cos(x), label='cosine')
plt.axis('tight')
plt.legend()

# %%
# Out:
# <module 'matplotlib.style' from '/Users/nmtarr/miniconda3/envs/range_eval/lib/python3.6/site-packages/matplotlib/style/__init__.py'>
