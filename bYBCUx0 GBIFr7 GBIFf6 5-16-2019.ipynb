# %% [markdown]
# # Yellow-billed Cuckoo - GBIF Records Summary
# This notebook is a tool for exploring data sets requested from GBIF (and eventually other sources), and mostly for developing criteria for filtering records (filter sets).  When the entire notebook is run, it retrieves records according to the filter sets specified and saves the results (records and some summary tables) in an sqlite database.  Some information is pulled from the parameters.sqlite database that is saved in the repository with the code that this notebook is built upon.
#
# Some potential uses of the data sets that can be developd with this tool:
# 1. ecological niche/species distribution modeling
# 2. delineating extents of occurrences
# 3. validating polygon depictions of species' ranges
# 4. comparison of species' sightings with other map layers

# %% [markdown]
# ### General Setup

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
#import geopandas as gpd
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 60)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()

# %% [markdown]
# ### Config file
# Some of the scripts below pull variables from a config file.  This is in order to reduce redundancy and also facilitates running scripts outside of jupyter notebooks.  However, variables need to be able to be set in notebooks too, so the cell below deletes and then rewrites the config file according to what you want for running this notebook.

# %%
# Set variables in the following text string, not variable assignment below.
text = """#NOTE! this is overwritten by some notebooks, so update everywhere, if adding lines.
sp_id = 'bybcux0'
summary_name = 'cuckoo'
gbif_req_id = 'GBIFr7'
gbif_filter_id = 'GBIFf6'
ebird_req_id = None
ebird_filter_id = None
evaluation = 'eval_gbif1'
workDir = '/Users/nmtarr/Documents/RANGES/'
codeDir = '/Users/nmtarr/Code/range_map_evaluation/'
inDir = workDir + 'Inputs/'
outDir = workDir + 'Outputs/'
default_coordUncertainty = 100
SRID_dict = {'WGS84': 4326, 'AlbersNAD83': 102008} # Used in file names for output.
spdb = outDir + sp_id + gbif_req_id + gbif_filter_id + '.sqlite'
"""
f = open('config.py', 'w')
f.write(text)
f.close()

import config
species_id = config.sp_id
summary_name = config.summary_name
request_id = config.gbif_req_id
filter_id = config.gbif_filter_id
inDir = config.inDir
outDir = config.outDir
print("Notebook run " + str(t1))
# Out:
# Notebook run 2019-05-16 09:55:37.285445

# %%
connjup = sqlite3.connect(config.codeDir + 'parameters.sqlite')
cursorjup = connjup.cursor()

# %% [markdown]
# # Species Concept
# Display information on the species from the parameters.sqlite database.

# %%
vals = cursorjup.execute("SELECT * FROM species_concepts WHERE species_id = '{0}';".format(species_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('species_concepts')").fetchall()]
pprint.pprint(dict(zip(cols, vals)))
# Out:
# {'bcb_id': None,
#  'breeding_months': '4,5,6,7,8',
#  'common_name': 'yellow-billed cuckoo',
#  'detection_distance_meters': 100,
#  'end_year': None,
#  'error_tolerance': 40,
#  'fws_id': None,
#  'gap_id': 'bybcux',
#  'gbif_id': '2496287',
#  'geometry': None,
#  'itis_tsn': '177831',
#  'migratory': '1',
#  'notes': 'Manually entered for use in development. ',
#  'pad': 2,
#  'scientific_name': 'Coccyzus americanus',
#  'species_id': 'bybcux0',
#  'start_year': None,
#  'wintering_months': '11,12,1,2'}

# %% [markdown]
# ## Filters
# Display the parameters of the request filter set.  These are deployed during the step where records are retrieved from the API.

# %%
df1 = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(request_id), con=connjup)
print("THE REQUEST FILTER SET")
print(df1.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id         GBIFr7
# source               GBIF
# lat_range           27,41
# lon_range         -91,-75
# years_range     2018,2019
# months_range         1,12
# geoissue             None
# coordinate           True
# continent            None
# creator           N. Tarr
# notes                None
# Name: 0, dtype: object

# %% [markdown]
# Display the parameters of the post-request filter set.  These are deployed after the records are retrieved from the API, but before they are stored in the occurrence record sqlite database.

# %%
df2 = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(df2.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                                                                          GBIFf6
# dataset                                                                              GBIF
# collection_codes_omit                                                                None
# institutions_omit                                                                    None
# has_coordinate_uncertainty                                                              0
# max_coordinate_uncertainty                                                            300
# bases_omit                                            PRESERVED_SPECIMEN, FOSSIL_SPECIMEN
# protocols_omit                                                                       None
# sampling_protocols_omit                                                              None
# issues_omit                   GEODETIC_DATUM_INVALID, INDIVIDUAL_COUNT_INVALID, MULTIM...
# creator                                                                           N. Tarr
# notes                                                                                None
# Name: 0, dtype: object

# %% [markdown]
# ### Filter set justification
# collection_codes_omit: No known reasons to omit.
#
# institutions_omit: No known reasons to omit.
#
# has_coordinate_uncertainty: Limiting on this would return only preserved specimens.
#
# max_coordinate_uncertainty: Modern records should have decent coordinate uncertainty.  If not, they are suspect.
#
# bases_omit: Preserved_specimens seem reliable for this species to me and fossils don't seem relevant to this application.
#
# protocols_omit: No known reasons to omit.
#
# sampling_protocols_omit: No known reasons to omit.
#
# issues_omit: Invalid datums create spatial error in point locations.  Invalid counts seem like a red flag for data quality.

# %%
# Run a script that retrieves and filters
# %run 'retrieve_occurrences.py'
# Out:
# downloading https://www.sciencebase.gov/catalog/file/get/59f5e201e4b063d5d307dc0f?f=__disk__89%2Fbb%2F19%2F89bb19045ef553fdf3a05056b81618649e77e351 to /Users/nmtarr/Documents/RANGES/Inputs/bYBCUx_CONUS_Range_2001v1.zip
# downloading https://www.sciencebase.gov/catalog/file/get/59f5e201e4b063d5d307dc0f?f=__disk__db%2Fb5%2F9a%2Fdbb59a7ae14e77d87bd9a6f527f91dd55e577628 to /Users/nmtarr/Documents/RANGES/Inputs/bYBCUx_CONUS_Range_2001v1.xml
# 85214 records exist with the request parameters
# near "s": syntax error
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 2, 'acceptedTaxonKey': 2496287, 'scientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'acceptedScientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -74.940971, 'decimalLatitude': 38.953483, 'year': 2018, 'month': 5, 'day': 26, 'eventDate': '2018-05-26T00:00:00', 'issues': [], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Cape Island--CMBO\'s "The Roost" (restricted access)', 'gbifID': '2179785207', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS624180793', 'remarks': '; Cape Island--CMBO\'s "The Roost" (restricted access)', 'dataGeneralizations': ''}
# near "54": syntax error
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 2, 'acceptedTaxonKey': 2496287, 'scientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'acceptedScientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.144901, 'decimalLatitude': 9.247086, 'year': 2018, 'month': 5, 'day': 4, 'eventDate': '2018-05-04T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Hacienda Flandes 9°11\'54"N-75°7\'26"W', 'gbifID': '2156127699', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS610711401', 'remarks': '; Hacienda Flandes 9°11\'54"N-75°7\'26"W', 'dataGeneralizations': ''}
# near "s": syntax error
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2496287, 'scientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'acceptedScientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -74.940971, 'decimalLatitude': 38.953483, 'year': 2018, 'month': 5, 'day': 14, 'eventDate': '2018-05-14T00:00:00', 'issues': [], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Cape Island--CMBO\'s "The Roost" (restricted access)', 'gbifID': '2162170300', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS617898964', 'remarks': '; Cape Island--CMBO\'s "The Roost" (restricted access)', 'dataGeneralizations': ''}
# near "s": syntax error
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 2, 'acceptedTaxonKey': 2496287, 'scientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'acceptedScientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -74.940971, 'decimalLatitude': 38.953483, 'year': 2018, 'month': 5, 'day': 26, 'eventDate': '2018-05-26T00:00:00', 'issues': [], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Cape Island--CMBO\'s "The Roost" (restricted access)', 'gbifID': '2172755163', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS623800454', 'remarks': '; Cape Island--CMBO\'s "The Roost" (restricted access)', 'dataGeneralizations': ''}
# near "s": syntax error
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2496287, 'scientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'acceptedScientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -74.940971, 'decimalLatitude': 38.953483, 'year': 2018, 'month': 5, 'day': 13, 'eventDate': '2018-05-13T00:00:00', 'issues': [], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Cape Island--CMBO\'s "The Roost" (restricted access)', 'gbifID': '2149728834', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS617379708', 'remarks': '; Cape Island--CMBO\'s "The Roost" (restricted access)', 'dataGeneralizations': ''}
# near "s": syntax error
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2496287, 'scientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'acceptedScientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -90.778656, 'decimalLatitude': 43.661911, 'year': 2018, 'month': 5, 'day': 25, 'eventDate': '2018-05-25T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': '"Paul and Bernadette\'s Tangled Bank"', 'gbifID': '2168711714', 'collectionCode': 'EBIRD_WI', 'occurrenceID': 'URN:catalog:CLO:EBIRD_WI:OBS624251029', 'remarks': '; "Paul and Bernadette\'s Tangled Bank"', 'dataGeneralizations': ''}
# near "s": syntax error
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2496287, 'scientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'acceptedScientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -74.940971, 'decimalLatitude': 38.953483, 'year': 2018, 'month': 5, 'day': 14, 'eventDate': '2018-05-14T00:00:00', 'issues': [], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Cape Island--CMBO\'s "The Roost" (restricted access)', 'gbifID': '2172778658', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS617834159', 'remarks': '; Cape Island--CMBO\'s "The Roost" (restricted access)', 'dataGeneralizations': ''}
# near "s": syntax error
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2496287, 'scientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'acceptedScientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -90.778656, 'decimalLatitude': 43.661911, 'year': 2018, 'month': 6, 'day': 10, 'eventDate': '2018-06-10T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': '"Paul and Bernadette\'s Tangled Bank"', 'gbifID': '2162910831', 'collectionCode': 'EBIRD_WI', 'occurrenceID': 'URN:catalog:CLO:EBIRD_WI:OBS630343530', 'remarks': '; "Paul and Bernadette\'s Tangled Bank"', 'dataGeneralizations': ''}
# near "s": syntax error
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2496287, 'scientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'acceptedScientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -74.940971, 'decimalLatitude': 38.953483, 'year': 2018, 'month': 7, 'day': 27, 'eventDate': '2018-07-27T00:00:00', 'issues': [], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Cape Island--CMBO\'s "The Roost" (restricted access)', 'gbifID': '2197896211', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS643481324', 'remarks': '; Cape Island--CMBO\'s "The Roost" (restricted access)', 'dataGeneralizations': ''}
# near "s": syntax error
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2496287, 'scientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'acceptedScientificName': 'Coccyzus americanus (Linnaeus, 1758)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -74.940971, 'decimalLatitude': 38.953483, 'year': 2018, 'month': 10, 'day': 16, 'eventDate': '2018-10-16T00:00:00', 'issues': [], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Cape Island--CMBO\'s "The Roost" (restricted access)', 'gbifID': '2207122329', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS667354763', 'remarks': '; Cape Island--CMBO\'s "The Roost" (restricted access)', 'dataGeneralizations': ''}
# Records saved in /Users/nmtarr/Documents/RANGES/Outputs/bybcux0GBIFr7GBIFf6.sqlite

# %% [markdown]
# ### How many records made it through the filters?
# This is the number that was actually saved in the occurrence record sqlite database.

# %%
conn_occ= sqlite3.connect(config.spdb)
curs_occ = conn_occ.cursor()
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE species_id = '{0}'".format(species_id)).fetchone()
print(str(record_count[0]) + " records")
# Out:
# 85136 records

# %% [markdown]
# ### Were there duplicate records?
# needs to be addressed

# %%
dups0 = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences GROUP BY geom_xy4326, occurrenceDate;").fetchall()
dups1 = [x[0] for x in dups0]
dups2 = [x for x in dups1 if x > 1]
print(str(len(dups2)) + ' records were duplicates based on xy coordinate and date-time')
# Out:
# 12522 records were duplicates based on xy coordinate and date-time

# %% [markdown]
# # Institutions
# #### Pre-filters

# %%
institutions = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'institutions';").fetchall()
for x in institutions:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# iNaturalist (391)
# CLO (84814)
# http://grbio.org/cool/iakn-125z (2)
# YPM (1)
# Instituto de Investigación de Recursos Biológicos Alexander von Humboldt (IAvH) (1)
# 900.003.825-8 (1)
# http://biocol.org/urn:lsid:biocol.org:col:34795 (1)
# unknown (2)
# Insituto de Investigación de Recursos Biológicos Alexander von Humboldt (IAvH) (1)

# %% [markdown]
# #### Post-filter

# %%
institutions = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'institutions' AND step = 'filter';").fetchone()[0]
institutions = institutions.replace('[', '').strip().replace(']', '').replace("'", "")
institutions = institutions.split(',')
for ins in institutions:
    print(ins.strip())
# Out:
# UNKNOWN
# Insituto de Investigación de Recursos Biológicos Alexander von Humboldt (IAvH)
# Instituto de Investigación de Recursos Biológicos Alexander von Humboldt (IAvH)
# WCS Colombia
# CLO
# iNaturalist

# %% [markdown]
# # Collections
# #### Pre-filters

# %%
collections = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'collections';").fetchall()
for x in collections:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# Observations (391)
# EBIRD (81945)
# EBIRD_PRY (4)
# EBIRD_QC (84)
# EBIRD_PE (7)
# EBIRD_WI (161)
# EBIRD_PNW (63)
# EBIRD_TX (520)
# EBIRD_CAMERICA (132)
# EBIRD_VA (244)
# EBIRD_MEX (80)
# EBIRD_ME (26)
# EBIRD_CAN (416)
# EBIRD_CB (95)
# EBIRD_KIOSK (4)
# EBIRD_COL (94)
# EBIRD_VINS (57)
# EBIRD_BRA (2)
# EBIRD_MA (30)
# EBIRD_AK (7)
# EBIRD_PA (355)
# EBIRD_NJ (210)
# EBIRD_PR (6)
# EBIRD_MO (154)
# EBIRD_NH (32)
# EBIRD_BCN (51)
# EBIRD_CL (10)
# EBIRD_IND (7)
# EBIRD_AU (11)
# EBIRD_ESP (3)
# Birds (3)
# VZ (1)
# Instituto de Investigación de Recursos Biológicos Alexander von Humboldt (IAvH) (1)
# UNKNOWN (1)
# Bird sounds (2)
# EBIRD_MYS (2)
# Insituto de Investigación de Recursos Biológicos Alexander von Humboldt (IAvH) (1)
# EBIRD_POR (1)
# EBIRD_ARG (1)

# %% [markdown]
# #### Post-filters

# %%
collections = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'collections' AND step = 'filter';").fetchone()[0]
collections = collections.replace('[', '').strip().replace(']', '').replace("'", "")
collections = collections.split(',')
for colls in collections:
    print(colls.strip())
# Out:
# EBIRD_POR
# EBIRD_BRA
# EBIRD_IND
# EBIRD_MYS
# EBIRD
# EBIRD_NJ
# Bird sounds
# EBIRD_CB
# EBIRD_PE
# EBIRD_CAN
# EBIRD_PRY
# EBIRD_BCN
# EBIRD_CAMERICA
# EBIRD_COL
# EBIRD_VA
# EBIRD_WI
# EBIRD_PA
# EBIRD_TX
# EBIRD_MO
# EBIRD_PR
# EBIRD_KIOSK
# EBIRD_ESP
# EBIRD_MA
# EBIRD_VINS
# EBIRD_QC
# EBIRD_AU
# EBIRD_AK
# Observations
# EBIRD_MEX
# EBIRD_ARG
# EBIRD_PNW
# Insituto de Investigación de Recursos Biológicos Alexander von Humboldt (IAvH)
# EBIRD_ME
# Instituto de Investigación de Recursos Biológicos Alexander von Humboldt (IAvH)
# EBIRD_CL
# EBIRD_NH

# %% [markdown]
# # Bases
# #### Pre-filter

# %%
bases = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'bases';").fetchall()
for x in bases:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# HUMAN_OBSERVATION (85210)
# PRESERVED_SPECIMEN (4)

# %% [markdown]
# #### Post-filters

# %%
bases = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'bases' AND step = 'filter';").fetchone()[0]
bases = bases.replace('[', '').strip().replace(']', '').replace("'", "")
bases = bases.split(",")
for bas in bases:
    print(bas.strip())
# Out:
# HUMAN_OBSERVATION

# %% [markdown]
# # Protocols
# #### Pre-filters

# %%
protocols = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'protocols';").fetchall()
for x in protocols:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# DWC_ARCHIVE (85214)

# %% [markdown]
# #### Post-filters

# %%
protos = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'protocols' AND step = 'filter';").fetchall()[0]
for pro in protos:
    pro = pro.replace('[', '').strip().replace(']', '').replace("'", "")
    print(pro)
# Out:
# eBird - Traveling Count, Censos visuales y auditivos, DWC_ARCHIVE

# %% [markdown]
# # Issues
# #### Pre-filters

# %%
issues = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'issues';").fetchall()
for x in issues:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# COORDINATE_ROUNDED (67220)
# GEODETIC_DATUM_ASSUMED_WGS84 (394)
# COORDINATE_UNCERTAINTY_METERS_INVALID (5)
# COUNTRY_INVALID (12)
# COUNTRY_DERIVED_FROM_COORDINATES (12)

# %% [markdown]
# #### Post-filters

# %%
issues = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'issues' AND step = 'filter';").fetchone()[0]
issues = issues.replace('[', '').strip().replace(']', '').replace("'", "")
issues = issues.split(',')
for iss in issues:
    print(iss.strip())
# Out:
# COUNTRY_INVALID
# COORDINATE_UNCERTAINTY_METERS_INVALID
# COUNTRY_DERIVED_FROM_COORDINATES
# COORDINATE_ROUNDED
# GEODETIC_DATUM_ASSUMED_WGS84

# %% [markdown]
# # Descriptions of filtered records

# %% [markdown]
# ### Locations

# %%
gap_range2 = "{0}{1}_range_4326".format(inDir, gap_id)

shp1 = {'file': gap_range2, 'column': None, 'alias': 'GAP range map',
        'drawbounds': False, 'linewidth': .5, 'linecolor': 'y',
        'fillcolor': 'y', 'marker':'s'}

shp2 = {'file': '{0}{1}_circles'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'k',
        'fillcolor': None, 'marker':'o'}

# Display occurrence polygons
if os.path.isfile(gap_range2 + ".shp"):
    map_these=[shp1, shp2]
else:
    map_these=[shp2]
    
title="{1} ({0})".format(years, common_name)
functions.MapShapefilePolygons(map_these=map_these, title=title)

# %% [markdown]
# ### Years represented

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(config.gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of occurrences")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# ### Months represented

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of occurrences")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# ### Distribution of coordinate uncertainty values

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %% [markdown]
# ### Geodetic datums present

# %%
datums = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'datums' AND step = 'filter';").fetchone()[0]
datums = datums.replace('[', '').strip().replace(']', '').replace("'", "")
datums = datums.split()
for datum in datums:
    print(datum)
# Out:
# WGS84

# %% [markdown]
# ### Establishment means reported

# %%
establishment = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'establishment' AND step = 'filter';").fetchall()[0]
for est in establishment:
    est = est.replace('[', '').strip().replace(']', '').replace("'", "")
    print(est)

# %% [markdown]
# ### Identification qualifiers included

# %%
quali = curs_occ.execute("SELECT DISTINCT vals FROM record_attributes WHERE field = 'IDqualifier' AND step = 'filter';").fetchall()[0]
for q in quali:
    q = q.replace('[', '').strip().replace(']', '').replace("'", "")
    print(q)

# %% [markdown]
# ### Remarks included

# %%
remarks = curs_occ.execute("SELECT DISTINCT remarks FROM occurrences;").fetchall()
#remarks = remarks.replace('[', '').strip().replace(']', '').replace("'", "")
#remarks = remarks.split(',')
if len(remarks) <= 20:
    for rem in remarks:
        if rem[0][0:1] == ';':
            print(rem[0][2:])
        else:
            print(rem[0])
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# More than 20 remarks, consult the occurrence database.

# %% [markdown]
# ### Sources

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [request_id, filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])
# Out:
# GBIF

# %% [markdown]
# ### Attributes returned for the records in the request (pre-filters)

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ, index_col='index')
fields_summary.index.name = 'field'
print(fields_summary)
# Out:
#                                       included(n)  populated(n)
# field
# acceptedScientificName                      85214         85214
# acceptedTaxonKey                            85214         85214
# accessRights                                    4             4
# basisOfRecord                               85214         85214
# behavior                                        2             2
# bibliographicCitation                           1             1
# catalogNumber                               85211         85211
# class                                       85214         85214
# classKey                                    85214         85214
# collectionCode                              85213         85213
# collectionID                                    3             3
# continent                                       5             5
# coordinateUncertaintyInMeters                 322           322
# country                                     85214         85214
# countryCode                                 85214         85214
# county                                      82408         82408
# crawlId                                     85214         85214
# dataGeneralizations                             1             1
# datasetID                                       2             2
# datasetKey                                  85214         85214
# datasetName                                   394           394
# dateIdentified                                393           393
# day                                         85214         85214
# decimalLatitude                             85214         85214
# decimalLongitude                            85214         85214
# dynamicProperties                               5             5
# elevation                                       2             2
# elevationAccuracy                               1             1
# endDayOfYear                                    2             2
# establishmentMeans                              2             2
# eventDate                                   85214         85214
# eventID                                         2             2
# eventTime                                     345           345
# extensions                                  85214             0
# facts                                       85214             0
# family                                      85214         85214
# familyKey                                   85214         85214
# fieldNotes                                      2             2
# fieldNumber                                     2             2
# gbifID                                      85214         85214
# genericName                                 85214         85214
# genus                                       85214         85214
# genusKey                                    85214         85214
# geodeticDatum                               85214         85214
# georeferenceProtocol                            4             4
# georeferenceSources                             1             1
# georeferenceVerificationStatus                  2             2
# georeferencedBy                                 1             1
# higherClassification                            6             6
# higherGeography                                 4             4
# http://unknown.org/occurrenceDetails          391           391
# identificationID                              390           390
# identificationRemarks                           1             1
# identifiedBy                                    3             3
# identifier                                  85214         85214
# identifiers                                 85214             0
# individualCount                             83873         83873
# informationWithheld                            12            12
# infraspecificEpithet                            8             8
# installationKey                             85214         85214
# institutionCode                             85212         85212
# institutionID                                   4             4
# issues                                      85214         67256
# key                                         85214         85214
# kingdom                                     85214         85214
# kingdomKey                                  85214         85214
# language                                        5             5
# lastCrawled                                 85214         85214
# lastInterpreted                             85214         85214
# lastParsed                                  85214         85214
# license                                     85214         85214
# lifeStage                                       1             1
# locality                                    84823         84823
# locationID                                      1             1
# locationRemarks                                 1             1
# media                                         359           359
# modified                                      395           395
# month                                       85214         85214
# municipality                                    1             1
# networkKeys                                 85214             0
# nomenclaturalCode                               6             6
# occurrenceID                                85214         85214
# occurrenceRemarks                              74            74
# occurrenceStatus                                2             2
# order                                       85214         85214
# orderKey                                    85214         85214
# organismID                                      1             1
# organismQuantity                                2             2
# organismQuantityType                            2             2
# otherCatalogNumbers                             2             2
# ownerInstitutionCode                            2             2
# phylum                                      85214         85214
# phylumKey                                   85214         85214
# preparations                                    4             4
# previousIdentifications                         1             1
# protocol                                    85214         85214
# publishingCountry                           85214         85214
# publishingOrgKey                            85214         85214
# recordNumber                                    2             2
# recordedBy                                  85211         85211
# references                                    396           396
# relations                                   85214             0
# reproductiveCondition                           1             1
# rights                                        391           391
# rightsHolder                                  396           396
# samplingProtocol                                3             3
# scientificName                              85214         85214
# sex                                             4             4
# species                                     85214         85214
# speciesKey                                  85214         85214
# specificEpithet                             85214         85214
# startDayOfYear                                  3             3
# stateProvince                               85212         85212
# taxonID                                       391           391
# taxonKey                                    85214         85214
# taxonRank                                   85214         85214
# taxonRemarks                                    1             1
# taxonomicStatus                             85214         85214
# type                                            5             5
# verbatimCoordinateSystem                        2             2
# verbatimElevation                               3             3
# verbatimEventDate                             395           395
# verbatimLocality                              393           393
# verbatimSRS                                     2             2
# vernacularName                                  5             5
# year                                        85214         85214

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
# Out:
# 3:37:31.943423
